# %%
import pandas as pd

# %%
df_metadata = pd.read_csv('cleaned_metadata.csv')

# %%
df_metadata
# Out:
#        adult                                             genres      id  \
# 0      False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      False  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      False  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      False  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4      False                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...      ...                                                ...     ...
# 32257  False           [{'id': 878, 'name': 'Science Fiction'}]  222848
# 32258  False  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 32259  False  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 32260  False                                                 []  227506
# 32261  False                                                 []  461257
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 32257  tt0112613                en              Caged Heat 3000
# 32258  tt0102797                en                   Robin Hood
# 32259  tt0303758                en                     Betrayal
# 32260  tt0008536                en          Satana likuyushchiy
# 32261  tt6980792                en                     Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 32257  It's the year 3000 AD. The world's most danger...    0.661558
# 32258  Yet another version of the classic epic, with ...    5.683753
# 32259  When one of her hits goes wrong, a professiona...    0.903007
# 32260  In a small town live two brothers, one a minis...    0.003503
# 32261  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 32257  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg
# 32258  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg
# 32259  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 32260  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 32261  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 32257    [{'name': 'Concorde-New Horizons', 'id': 4688}]
# 32258  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 32259  [{'name': 'American World Pictures', 'id': 6165}]
# 32260               [{'name': 'Yermoliev', 'id': 88753}]
# 32261                                                 []
#
#                                     production_countries  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                  ...
# 32257  [{'iso_3166_1': 'US', 'name': 'United States o...
# 32258  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 32259  [{'iso_3166_1': 'US', 'name': 'United States o...
# 32260           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 32261   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#
#                                         spoken_languages  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2               [{'iso_639_1': 'en', 'name': 'English'}]
# 3               [{'iso_639_1': 'en', 'name': 'English'}]
# 4               [{'iso_639_1': 'en', 'name': 'English'}]
# ...                                                  ...
# 32257           [{'iso_639_1': 'en', 'name': 'English'}]
# 32258           [{'iso_639_1': 'en', 'name': 'English'}]
# 32259           [{'iso_639_1': 'en', 'name': 'English'}]
# 32260                                                 []
# 32261           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 32257                                                NaN
# 32258                                                NaN
# 32259                             A deadly game of wits.
# 32260                                                NaN
# 32261                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 32257              Caged Heat 3000           3.5         1.0
# 32258                   Robin Hood           5.7        26.0
# 32259                     Betrayal           3.8         6.0
# 32260             Satan Triumphant           0.0         0.0
# 32261                     Queerama           0.0         0.0
#
# [32262 rows x 16 columns]

# %%
from sentence_transformers import SentenceTransformer
sentences = []

# %%
for row in df_metadata.itertuples(index=True):
    if row.overview is not None:
        sentences.append(str(row.overview))

# %%
print(len(sentences))
print(sentences[0])
# Out:
# 32262
# Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.

# %%
#creating embeddings for all of the sentences.
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = model.encode(sentences)
print(embeddings.shape)
# Out:
# (32262, 384)

# %%
import numpy as np

np.save('embeddings.npy', embeddings)
